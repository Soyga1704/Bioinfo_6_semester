# %% [markdown]
# <span style='font-size: 24px'> **Задание №1** </span>

# %% [markdown]
# Найти от 3 до 5 последовательностей S-белка SARS-CoV-2 в открытых источниках. Добавить к ним какую-нибудь из последовательностей, рассмотренных на семинаре. Построить для них филогенетическое дерево, сделать выводы.

# %% [markdown]
# Выбираем последовательности S-белка Covid-19, выравниваем с помощью MEGA12 и считаем Distances.

# %% [markdown]
# ![image.png](attachment:eab238f6-a759-4c5e-b65a-b4f64766b3c1.png)

# %% [markdown]
# Строим филогенетическое древо.

# %% [markdown]
# ![image.png](attachment:ddb4053b-c6f9-4243-8def-3e5c11aad9fd.png)

# %% [markdown]
# **Вывод:** чем меньше разница в номерах последовательностей, тем они ближе друг к другу в дереве. Последовательности 10853, 10922, 10694 и 10720 эволюционно близки друг к другу, а 4568 находится далеко от них.

# %% [markdown]
# <span style='font-size: 24px'> **Задание №2** </span>

# %% [markdown]
# Найти в базе данных ортологов последовательности (от 4 до 10) на ваш вкус и построить для них филогенетическое дерево, также сделать выводы.

# %% [markdown]
# Находим в NCBI ортологов белка phosphatidylinositol phospholipase C (PLC1), выравниваем их в MEGA12, считаем Distances и строим филогенетическое древо.

# %% [markdown]
# ![image.png](attachment:af2d44cc-c4c5-41f9-a8b2-20ce8ca2e887.png)

# %% [markdown]
# ![image.png](attachment:22d140ae-b802-49f8-80a8-093b6e4f0d2e.png)

# %% [markdown]
# **Вывод:** Candida albicans, Candida dubliniensis и Candida subhashii являются наиболее близкими видами, так как они принадлежат к одному роду. Scheffersomyces stipitis и Komagataelle phaffii эволюционно далеко от рода Candida, судя по генетическим расстояниям.
